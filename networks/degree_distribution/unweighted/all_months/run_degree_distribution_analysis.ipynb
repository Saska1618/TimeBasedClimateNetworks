# %%
# !python analyze_monthly_degrees.py
# Out:
# Processing degree distributions for: Bacskatopolya...
#   - Saved plot to /Users/saska/Documents/research/TimeBasedClimateNetworks/plots/degree_distributions/unweighted/all_months/Bacskatopolya_monthly_degree_distribution.png
#   - Saved stats to /Users/saska/Documents/research/TimeBasedClimateNetworks/networks/degree_distribution/unweighted/all_months/monthly_degrees/Bacskatopolya_monthly_degree_stats.json
# Processing degree distributions for: Brasov...
#   - Saved plot to /Users/saska/Documents/research/TimeBasedClimateNetworks/plots/degree_distributions/unweighted/all_months/Brasov_monthly_degree_distribution.png
#   - Saved stats to /Users/saska/Documents/research/TimeBasedClimateNetworks/networks/degree_distribution/unweighted/all_months/monthly_degrees/Brasov_monthly_degree_stats.json
# Processing degree distributions for: Cluj...
# ...

# %%
# !python analyze_monthly_degrees.py
# Out:
# Processing degree distributions (close months) for: Bacskatopolya...
#   - Saved plot to /Users/saska/Documents/research/TimeBasedClimateNetworks/plots/degree_distributions/unweighted/close_months/Bacskatopolya_monthly_degree_distribution_close_months.png
#   - Saved stats to /Users/saska/Documents/research/TimeBasedClimateNetworks/networks/degree_distribution/unweighted/close_months/monthly_degrees/Bacskatopolya_monthly_degree_stats_close_months.json
# Processing degree distributions (close months) for: Brasov...
#   - Saved plot to /Users/saska/Documents/research/TimeBasedClimateNetworks/plots/degree_distributions/unweighted/close_months/Brasov_monthly_degree_distribution_close_months.png
#   - Saved stats to /Users/saska/Documents/research/TimeBasedClimateNetworks/networks/degree_distribution/unweighted/close_months/monthly_degrees/Brasov_monthly_degree_stats_close_months.json
# Processing degree distributions (close months) for: Cluj...
# ...

# %%
# !python analyze_monthly_degrees.py
# Out:
# Processing weighted degree distributions for: Bacskatopolya...
#   - Saved plot to /Users/saska/Documents/research/TimeBasedClimateNetworks/plots/degree_distributions/weighted/all_months/Bacskatopolya_monthly_weighted_degree_distribution.png
#   - Saved stats to /Users/saska/Documents/research/TimeBasedClimateNetworks/networks/degree_distribution/weighted/all_months/monthly_degrees/Bacskatopolya_monthly_weighted_degree_stats.json
# Processing weighted degree distributions for: Brasov...
#   - Saved plot to /Users/saska/Documents/research/TimeBasedClimateNetworks/plots/degree_distributions/weighted/all_months/Brasov_monthly_weighted_degree_distribution.png
#   - Saved stats to /Users/saska/Documents/research/TimeBasedClimateNetworks/networks/degree_distribution/weighted/all_months/monthly_degrees/Brasov_monthly_weighted_degree_stats.json
# Processing weighted degree distributions for: Cluj...
# ...

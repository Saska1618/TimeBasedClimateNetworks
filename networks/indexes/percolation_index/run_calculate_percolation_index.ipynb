# %%
# !python calculate_percolation_index.py
# Out:
# [Bacskatopolya] Early: 0.9589 | Late: 0.9548 | Index: -0.0041
# [Brasov] Early: 0.9657 | Late: 0.9580 | Index: -0.0076
# [Cluj] Early: 0.9661 | Late: 0.9661 | Index: +0.0000
# [Deva] Early: 0.9648 | Late: 0.9609 | Index: -0.0039
# [Gheorgheni] Early: 0.9555 | Late: 0.9666 | Index: +0.0111
# [Gyor] Early: 0.9533 | Late: 0.9533 | Index: +0.0000
# [Kassa] Early: 0.9570 | Late: 0.9570 | Index: +0.0000
# [Kecskemet] Early: 0.9689 | Late: 0.9650 | Index: -0.0039
# [Keszthely] Early: 0.9574 | Late: 0.9616 | Index: +0.0043
# [Oradea] Early: 0.9631 | Late: 0.9631 | Index: +0.0000
# [Pecs] Early: 0.9667 | Late: 0.9584 | Index: -0.0083
#
# Calculated percolation index for 11 cities.
# Results saved to /Users/saska/Documents/research/TimeBasedClimateNetworks/networks/indexes/percolation_index/percolation_index.json

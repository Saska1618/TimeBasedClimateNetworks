# %%
# !python fragmentation_degree_dist_index.py
# Out:
# Processing Bacskatopolya...
# Processing Brasov...
# Processing Cluj...
# Processing Deva...
# Processing Gheorgheni...
# Processing Gyor...
# Processing Kassa...
# Processing Kecskemet...
# Processing Keszthely...
# Processing Oradea...
# Processing Pecs...
#
# Fragmentation degree distribution indices saved to /Users/saska/Documents/research/TimeBasedClimateNetworks/networks/indexes/fragmentation_degree_dist_index/results/fragmentation_degree_dist_index.json

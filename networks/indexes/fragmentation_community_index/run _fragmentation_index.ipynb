# %%
# !python fragmentation_index.py
# Out:
# Processing Bacskatopolya...
#     - Detected 3 total communities in the graph.
#     - Detected 4 total communities in the graph.
# Processing Brasov...
#     - Detected 4 total communities in the graph.
#     - Detected 4 total communities in the graph.
# Processing Cluj...
#     - Detected 3 total communities in the graph.
#     - Detected 3 total communities in the graph.
# Processing Deva...
#     - Detected 3 total communities in the graph.
#     - Detected 4 total communities in the graph.
# Processing Gheorgheni...
#     - Detected 3 total communities in the graph.
#     - Detected 4 total communities in the graph.
# Processing Gyor...
#     - Detected 3 total communities in the graph.
#     - Detected 4 total communities in the graph.
# Processing Kassa...
#     - Detected 4 total communities in the graph.
#     - Detected 3 total communities in the graph.
# Processing Kecskemet...
#     - Detected 3 total communities in the graph.
# ...

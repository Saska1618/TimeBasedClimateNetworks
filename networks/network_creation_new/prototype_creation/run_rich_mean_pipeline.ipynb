# %%
# !python rich_mean_prototype_creation.py
# Out:
# Processing city: Bacskatopolya...
#   - Early Month 1 computed.
#   - Early Month 2 computed.
#   - Early Month 3 computed.
#   - Early Month 4 computed.
#   - Early Month 5 computed.
#   - Early Month 6 computed.
#   - Early Month 7 computed.
#   - Early Month 8 computed.
#   - Early Month 9 computed.
#   - Early Month 10 computed.
#   - Early Month 11 computed.
#   - Early Month 12 computed.
#   - Late Month 1 computed.
#   - Late Month 2 computed.
#   - Late Month 3 computed.
#   - Late Month 4 computed.
#   - Late Month 5 computed.
#   - Late Month 6 computed.
#   - Late Month 7 computed.
#   - Late Month 8 computed.
#   - Late Month 9 computed.
#   - Late Month 10 computed.
#   - Late Month 11 computed.
#   - Late Month 12 computed.
# Processing city: Brasov...
#   - Early Month 1 computed.
#   - Early Month 2 computed.
#   - Early Month 3 computed.
#   - Early Month 4 computed.
#   - Early Month 5 computed.
#   - Early Month 6 computed.
#   - Early Month 7 computed.
# ...

# %%
# !python rich_mean_prototype_analysis.py
# Out:
# Processing city: Bacskatopolya...
#   - Using threshold: 0.0000
#   - Matrix for Bacskatopolya created.
# Processing city: Brasov...
#   - Using threshold: 0.0000
#   - Matrix for Brasov created.
# Processing city: Cluj...
#   - Using threshold: 0.0000
#   - Matrix for Cluj created.
# Processing city: Deva...
#   - Using threshold: 0.0000
#   - Matrix for Deva created.
# Processing city: Gheorgheni...
#   - Using threshold: 0.0000
#   - Matrix for Gheorgheni created.
# Processing city: Gyor...
#   - Using threshold: 0.0000
#   - Matrix for Gyor created.
# Processing city: Kassa...
#   - Using threshold: 0.0000
#   - Matrix for Kassa created.
# Processing city: Kecskemet...
#   - Using threshold: 0.0000
#   - Matrix for Kecskemet created.
# Processing city: Keszthely...
#   - Using threshold: 0.0000
#   - Matrix for Keszthely created.
# Processing city: Oradea...
#   - Using threshold: 0.0000
#   - Matrix for Oradea created.
# Processing city: Pecs...
#   - Using threshold: 0.0000
# ...

# %%
# !python visualize_rich_mean_matrices.py
# Out:
# Output directory: /Users/saska/Documents/research/TimeBasedClimateNetworks/plots/mean_heatmaps
# Processing city: Bacskatopolya...
#   - Saved heatmap to /Users/saska/Documents/research/TimeBasedClimateNetworks/plots/mean_heatmaps/no_threshold/rich_mean_Bacskatopolya_heatmap_no_threshold.png
# Processing city: Brasov...
#   - Saved heatmap to /Users/saska/Documents/research/TimeBasedClimateNetworks/plots/mean_heatmaps/no_threshold/rich_mean_Brasov_heatmap_no_threshold.png
# Processing city: Cluj...
#   - Saved heatmap to /Users/saska/Documents/research/TimeBasedClimateNetworks/plots/mean_heatmaps/no_threshold/rich_mean_Cluj_heatmap_no_threshold.png
# Processing city: Deva...
#   - Saved heatmap to /Users/saska/Documents/research/TimeBasedClimateNetworks/plots/mean_heatmaps/no_threshold/rich_mean_Deva_heatmap_no_threshold.png
# Processing city: Gheorgheni...
# ...

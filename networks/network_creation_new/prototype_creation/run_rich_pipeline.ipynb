# %% [markdown]
# # Rich Network Prototypes Pipeline
#
# This notebook sequentially runs the scripts required to create, analyze, and visualize the "rich" climate network prototypes (which incorporate tn, tx, tg, rr, qq, and hu).

# %% [markdown]
# ### 1. Create Rich Prototypes
# Extracts features from the `.graphml` files, runs PCA, calculates medoid prototypes for the early and late periods, and saves them to `prototypes/rich_prototypes.json`.

# %%
# !python rich_prototype_creation.py
# Out:
# Processing city: Bacskatopolya...
#   - Early Month 1: 1962-01
#   - Early Month 2: 1961-02
#   - Early Month 3: 1980-03
#   - Early Month 4: 1964-04
#   - Early Month 5: 1972-05
#   - Early Month 6: 1984-06
#   - Early Month 7: 1973-07
#   - Early Month 8: 1981-08
#   - Early Month 9: 1962-09
#   - Early Month 10: 1979-10
#   - Early Month 11: 1971-11
#   - Early Month 12: 1973-12
#   - Late Month 1: 2019-01
#   - Late Month 2: 2017-02
#   - Late Month 3: 2015-03
#   - Late Month 4: 2008-04
#   - Late Month 5: 2012-05
#   - Late Month 6: 1997-06
#   - Late Month 7: 2002-07
#   - Late Month 8: 2021-08
#   - Late Month 9: 2015-09
#   - Late Month 10: 2017-10
#   - Late Month 11: 1997-11
#   - Late Month 12: 2004-12
# Processing city: Brasov...
#   - Early Month 1: 1977-01
#   - Early Month 2: 1981-02
#   - Early Month 3: 1965-03
#   - Early Month 4: 1981-04
#   - Early Month 5: 1981-05
#   - Early Month 6: 1980-06
#   - Early Month 7: 1981-07
#   - Early Month 8: 1987-08
# ...

# %% [markdown]
# ### 2. Analyze Prototypes and Build Similarity Matrices
# Calculates Euclidean distances between the early and late prototypes, applies the strictest network threshold per city, and outputs `prototypes/rich_similarity_matrices.json`.

# %%
# !python rich_prototype_analysis.py
# Out:
# Processing city: Bacskatopolya...
#   - Using threshold: 0.8003
#   - Matrix for Bacskatopolya created.
# Processing city: Brasov...
#   - Using threshold: 0.8126
#   - Matrix for Brasov created.
# Processing city: Cluj...
#   - Using threshold: 0.8120
#   - Matrix for Cluj created.
# Processing city: Deva...
#   - Using threshold: 0.8085
#   - Matrix for Deva created.
# Processing city: Gheorgheni...
#   - Using threshold: 0.8162
#   - Matrix for Gheorgheni created.
# Processing city: Gyor...
#   - Using threshold: 0.7915
#   - Matrix for Gyor created.
# Processing city: Kassa...
#   - Using threshold: 0.7894
#   - Matrix for Kassa created.
# Processing city: Kecskemet...
#   - Using threshold: 0.8030
#   - Matrix for Kecskemet created.
# Processing city: Keszthely...
#   - Using threshold: 0.7897
#   - Matrix for Keszthely created.
# Processing city: Oradea...
#   - Using threshold: 0.8013
#   - Matrix for Oradea created.
# Processing city: Pecs...
#   - Using threshold: 0.7949
# ...

# %% [markdown]
# ### 3. Visualize the Matrices
# Reads the JSON matrices and generates Seaborn heatmaps for each city, saving the PNGs to `plots/similarity_heatmaps/`.

# %%
# !python visualize_rich_matrices.py
# Out:
# Output directory: /Users/saska/Documents/research/TimeBasedClimateNetworks/plots/heatmaps
# Processing city: Bacskatopolya...
#   - Saved heatmap to /Users/saska/Documents/research/TimeBasedClimateNetworks/plots/heatmaps/with_threshold/rich_Bacskatopolya_heatmap.png
# Processing city: Brasov...
#   - Saved heatmap to /Users/saska/Documents/research/TimeBasedClimateNetworks/plots/heatmaps/with_threshold/rich_Brasov_heatmap.png
# Processing city: Cluj...
#   - Saved heatmap to /Users/saska/Documents/research/TimeBasedClimateNetworks/plots/heatmaps/with_threshold/rich_Cluj_heatmap.png
# Processing city: Deva...
#   - Saved heatmap to /Users/saska/Documents/research/TimeBasedClimateNetworks/plots/heatmaps/with_threshold/rich_Deva_heatmap.png
# Processing city: Gheorgheni...
#   - Saved heatmap to /Users/saska/Documents/research/TimeBasedClimateNetworks/plots/heatmaps/with_threshold/rich_Gheorgheni_heatmap.png
# Processing city: Gyor...
# ...

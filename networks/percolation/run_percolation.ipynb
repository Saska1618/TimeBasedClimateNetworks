# %%
# !python percolation_analysis.py
# Out:
# Processing percolation for Bacskatopolya...
#   - Simulating early period...
#   - Simulating late period...
#   - Saved comparison plot to /Users/saska/Documents/research/TimeBasedClimateNetworks/networks/percolation/plots/Bacskatopolya_percolation_comparison.png
# Processing percolation for Brasov...
#   - Simulating early period...
#   - Simulating late period...
#   - Saved comparison plot to /Users/saska/Documents/research/TimeBasedClimateNetworks/networks/percolation/plots/Brasov_percolation_comparison.png
# Processing percolation for Cluj...
#   - Simulating early period...
#   - Simulating late period...
#   - Saved comparison plot to /Users/saska/Documents/research/TimeBasedClimateNetworks/networks/percolation/plots/Cluj_percolation_comparison.png
# Processing percolation for Deva...
#   - Simulating early period...
#   - Simulating late period...
# ...

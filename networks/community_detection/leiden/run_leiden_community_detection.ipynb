# %%
# !python leiden_community_detection.py
# Out:
# Loading Keszthely_1961-01_1990-12.graphml...
#   - Running Leiden algorithm...
#   - Found 3 communities (Modularity: 0.5020)
#   - Saved plot to /Users/saska/Documents/research/TimeBasedClimateNetworks/networks/community_detection/leiden/plots/Keszthely_1961-01_1990-12_leiden.png
# Loading Gheorgheni_1961-01_2024-12.graphml...
#   - Running Leiden algorithm...
#   - Found 3 communities (Modularity: 0.5110)
#   - Saved plot to /Users/saska/Documents/research/TimeBasedClimateNetworks/networks/community_detection/leiden/plots/Gheorgheni_1961-01_2024-12_leiden.png
# Loading Brasov_1961-01_2024-12.graphml...
#   - Running Leiden algorithm...
#   - Found 3 communities (Modularity: 0.5095)
#   - Saved plot to /Users/saska/Documents/research/TimeBasedClimateNetworks/networks/community_detection/leiden/plots/Brasov_1961-01_2024-12_leiden.png
# Loading Bacskatopolya_1961-01_2024-12.graphml...
#   - Running Leiden algorithm...
#   - Found 3 communities (Modularity: 0.5012)
# ...

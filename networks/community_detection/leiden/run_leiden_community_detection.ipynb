# %%
# !python leiden_community_detection.py
# Out:
# Processing Keszthely_1961-01_1990-12...
#   - Finding optimal resolution for 4 communities...
#   - Finding optimal resolution for 12 communities...
#   => Running for Base Resolution (1.0)
#   - Running Leiden algorithm (resolution=1.0000)...
#   - Found 3 communities (Modularity: 14421.1294)
#   - Saved plot to /Users/saska/Documents/research/TimeBasedClimateNetworks/networks/community_detection/leiden/plots/Keszthely_1961-01_1990-12_leiden_base.png
#   => Running for Target 4 Communities
#   - Running Leiden algorithm (resolution=1.5632)...
#   - Found 5 communities (Modularity: 9455.3440)
#   - Saved plot to /Users/saska/Documents/research/TimeBasedClimateNetworks/networks/community_detection/leiden/plots/Keszthely_1961-01_1990-12_leiden_target_4.png
#   => Running for Target 12 Communities
#   - Running Leiden algorithm (resolution=2.2271)...
#   - Found 11 communities (Modularity: 5463.3540)
# ...
